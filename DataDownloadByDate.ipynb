# %%
import os
import requests
import zipfile
import pandas as pd
from bs4 import BeautifulSoup
from clickhouse_driver import Client
from datetime import datetime

# %%
# Configuration
GDELT_BASE_URL = "http://data.gdeltproject.org/events/"
DOWNLOAD_DIR = "./gdelt_data"
EXTRACTED_DIR = "./gdelt_data/extracted"
CLICKHOUSE_HOST = "localhost"
CLICKHOUSE_PORT = 9000
CLICKHOUSE_DATABASE = "your_database"
CLICKHOUSE_TABLE = "your_table"

# %%
# Create necessary directories
os.makedirs(DOWNLOAD_DIR, exist_ok=True)
os.makedirs(EXTRACTED_DIR, exist_ok=True)

# %%
def list_files(base_url):
    try:
        response = requests.get(base_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        links = soup.find_all('a')
        files = [link.get('href') for link in links if link.get('href').endswith('.zip')]
        return files
    except requests.HTTPError as e:
        print(f"Failed to list files: {e}")
        return []

# %%
def download_file(url, local_filename):
    try:
        response = requests.get(url)
        response.raise_for_status()
        with open(local_filename, 'wb') as f:
            f.write(response.content)
        print(f"Downloaded {url} to {local_filename}")
    except requests.HTTPError as e:
        print(f"Failed to download {url}: {e}")

# %%
def unzip_file(zip_path, extract_to):
    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)
        print(f"Unzipped {zip_path} to {extract_to}")
    except zipfile.BadZipFile as e:
        print(f"Failed to unzip {zip_path}: {e}")

# %%
def process_files(extracted_dir):
    files = [os.path.join(extracted_dir, f) for f in os.listdir(extracted_dir) if f.endswith('.csv')]
    client = Client(host=CLICKHOUSE_HOST, port=CLICKHOUSE_PORT)
    for file in files:
        df = pd.read_csv(file)
        # Example: Filter for MCC related entries in Nepal
        df_filtered = df[(df['Actor1CountryCode'] == 'NP') & (df['Actor1Name'].str.contains('MCC', na=False))]
        if not df_filtered.empty:
            # Insert into ClickHouse
            columns = ", ".join(df_filtered.columns)
            values = [tuple(row) for row in df_filtered.values]
            try:
                client.execute(f'INSERT INTO {CLICKHOUSE_DATABASE}.{CLICKHOUSE_TABLE} ({columns}) VALUES', values)
                print(f"Inserted data from {file} into ClickHouse")
            except Exception as e:
                print(f"Failed to insert data from {file} into ClickHouse: {e}")

# %%
def main():
    start_date = datetime(2018, 1, 1)
    end_date = datetime(2018, 12, 31)
    
    files = list_files(GDELT_BASE_URL)
    print("Available files:")
    for file in files:
        # Extract the date part from the filename (assuming it's the first 8 characters)
        file_date_str = file[:8]
        try:
            file_date = datetime.strptime(file_date_str, '%Y%m%d')
        except ValueError:
            print(f"Skipping file with invalid date format: {file}")
            continue
        
        # Check if the file date is within the desired range
        if start_date <= file_date <= end_date:
            print(file)
            file_url = os.path.join(GDELT_BASE_URL, file)
            local_filename = os.path.join(DOWNLOAD_DIR, file)
            
            # Download the file
            download_file(file_url, local_filename)
            
            # Unzip the file
            unzip_file(local_filename, EXTRACTED_DIR)

    # Process extracted files
    process_files(EXTRACTED_DIR)

if __name__ == "__main__":
    main()
# Out:
# Available files:
# Skipping file with invalid date format: GDELT.MASTERREDUCEDV2.1979-2013.zip
# 20181231.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181231.export.CSV.zip to ./gdelt_data\20181231.export.CSV.zip
# Unzipped ./gdelt_data\20181231.export.CSV.zip to ./gdelt_data/extracted
# 20181230.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181230.export.CSV.zip to ./gdelt_data\20181230.export.CSV.zip
# Unzipped ./gdelt_data\20181230.export.CSV.zip to ./gdelt_data/extracted
# 20181229.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181229.export.CSV.zip to ./gdelt_data\20181229.export.CSV.zip
# Unzipped ./gdelt_data\20181229.export.CSV.zip to ./gdelt_data/extracted
# 20181228.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181228.export.CSV.zip to ./gdelt_data\20181228.export.CSV.zip
# Unzipped ./gdelt_data\20181228.export.CSV.zip to ./gdelt_data/extracted
# 20181227.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181227.export.CSV.zip to ./gdelt_data\20181227.export.CSV.zip
# Unzipped ./gdelt_data\20181227.export.CSV.zip to ./gdelt_data/extracted
# 20181226.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181226.export.CSV.zip to ./gdelt_data\20181226.export.CSV.zip
# Unzipped ./gdelt_data\20181226.export.CSV.zip to ./gdelt_data/extracted
# 20181225.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181225.export.CSV.zip to ./gdelt_data\20181225.export.CSV.zip
# Unzipped ./gdelt_data\20181225.export.CSV.zip to ./gdelt_data/extracted
# 20181224.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181224.export.CSV.zip to ./gdelt_data\20181224.export.CSV.zip
# Unzipped ./gdelt_data\20181224.export.CSV.zip to ./gdelt_data/extracted
# 20181223.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181223.export.CSV.zip to ./gdelt_data\20181223.export.CSV.zip
# Unzipped ./gdelt_data\20181223.export.CSV.zip to ./gdelt_data/extracted
# 20181222.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181222.export.CSV.zip to ./gdelt_data\20181222.export.CSV.zip
# Unzipped ./gdelt_data\20181222.export.CSV.zip to ./gdelt_data/extracted
# 20181221.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181221.export.CSV.zip to ./gdelt_data\20181221.export.CSV.zip
# Unzipped ./gdelt_data\20181221.export.CSV.zip to ./gdelt_data/extracted
# 20181220.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181220.export.CSV.zip to ./gdelt_data\20181220.export.CSV.zip
# Unzipped ./gdelt_data\20181220.export.CSV.zip to ./gdelt_data/extracted
# 20181219.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181219.export.CSV.zip to ./gdelt_data\20181219.export.CSV.zip
# Unzipped ./gdelt_data\20181219.export.CSV.zip to ./gdelt_data/extracted
# 20181218.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181218.export.CSV.zip to ./gdelt_data\20181218.export.CSV.zip
# Unzipped ./gdelt_data\20181218.export.CSV.zip to ./gdelt_data/extracted
# 20181217.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181217.export.CSV.zip to ./gdelt_data\20181217.export.CSV.zip
# Unzipped ./gdelt_data\20181217.export.CSV.zip to ./gdelt_data/extracted
# 20181216.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181216.export.CSV.zip to ./gdelt_data\20181216.export.CSV.zip
# Unzipped ./gdelt_data\20181216.export.CSV.zip to ./gdelt_data/extracted
# 20181215.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181215.export.CSV.zip to ./gdelt_data\20181215.export.CSV.zip
# Unzipped ./gdelt_data\20181215.export.CSV.zip to ./gdelt_data/extracted
# 20181214.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181214.export.CSV.zip to ./gdelt_data\20181214.export.CSV.zip
# Unzipped ./gdelt_data\20181214.export.CSV.zip to ./gdelt_data/extracted
# 20181213.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181213.export.CSV.zip to ./gdelt_data\20181213.export.CSV.zip
# Unzipped ./gdelt_data\20181213.export.CSV.zip to ./gdelt_data/extracted
# 20181212.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181212.export.CSV.zip to ./gdelt_data\20181212.export.CSV.zip
# Unzipped ./gdelt_data\20181212.export.CSV.zip to ./gdelt_data/extracted
# 20181211.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181211.export.CSV.zip to ./gdelt_data\20181211.export.CSV.zip
# Unzipped ./gdelt_data\20181211.export.CSV.zip to ./gdelt_data/extracted
# 20181210.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181210.export.CSV.zip to ./gdelt_data\20181210.export.CSV.zip
# Unzipped ./gdelt_data\20181210.export.CSV.zip to ./gdelt_data/extracted
# 20181209.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181209.export.CSV.zip to ./gdelt_data\20181209.export.CSV.zip
# Unzipped ./gdelt_data\20181209.export.CSV.zip to ./gdelt_data/extracted
# 20181208.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181208.export.CSV.zip to ./gdelt_data\20181208.export.CSV.zip
# Unzipped ./gdelt_data\20181208.export.CSV.zip to ./gdelt_data/extracted
# 20181207.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181207.export.CSV.zip to ./gdelt_data\20181207.export.CSV.zip
# Unzipped ./gdelt_data\20181207.export.CSV.zip to ./gdelt_data/extracted
# 20181206.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181206.export.CSV.zip to ./gdelt_data\20181206.export.CSV.zip
# Unzipped ./gdelt_data\20181206.export.CSV.zip to ./gdelt_data/extracted
# 20181205.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181205.export.CSV.zip to ./gdelt_data\20181205.export.CSV.zip
# Unzipped ./gdelt_data\20181205.export.CSV.zip to ./gdelt_data/extracted
# 20181204.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181204.export.CSV.zip to ./gdelt_data\20181204.export.CSV.zip
# Unzipped ./gdelt_data\20181204.export.CSV.zip to ./gdelt_data/extracted
# 20181203.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181203.export.CSV.zip to ./gdelt_data\20181203.export.CSV.zip
# Unzipped ./gdelt_data\20181203.export.CSV.zip to ./gdelt_data/extracted
# 20181202.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181202.export.CSV.zip to ./gdelt_data\20181202.export.CSV.zip
# Unzipped ./gdelt_data\20181202.export.CSV.zip to ./gdelt_data/extracted
# 20181201.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181201.export.CSV.zip to ./gdelt_data\20181201.export.CSV.zip
# Unzipped ./gdelt_data\20181201.export.CSV.zip to ./gdelt_data/extracted
# 20181130.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181130.export.CSV.zip to ./gdelt_data\20181130.export.CSV.zip
# Unzipped ./gdelt_data\20181130.export.CSV.zip to ./gdelt_data/extracted
# 20181129.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181129.export.CSV.zip to ./gdelt_data\20181129.export.CSV.zip
# Unzipped ./gdelt_data\20181129.export.CSV.zip to ./gdelt_data/extracted
# 20181128.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181128.export.CSV.zip to ./gdelt_data\20181128.export.CSV.zip
# Unzipped ./gdelt_data\20181128.export.CSV.zip to ./gdelt_data/extracted
# 20181127.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181127.export.CSV.zip to ./gdelt_data\20181127.export.CSV.zip
# Unzipped ./gdelt_data\20181127.export.CSV.zip to ./gdelt_data/extracted
# 20181126.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181126.export.CSV.zip to ./gdelt_data\20181126.export.CSV.zip
# Unzipped ./gdelt_data\20181126.export.CSV.zip to ./gdelt_data/extracted
# 20181125.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181125.export.CSV.zip to ./gdelt_data\20181125.export.CSV.zip
# Unzipped ./gdelt_data\20181125.export.CSV.zip to ./gdelt_data/extracted
# 20181124.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181124.export.CSV.zip to ./gdelt_data\20181124.export.CSV.zip
# Unzipped ./gdelt_data\20181124.export.CSV.zip to ./gdelt_data/extracted
# 20181123.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181123.export.CSV.zip to ./gdelt_data\20181123.export.CSV.zip
# Unzipped ./gdelt_data\20181123.export.CSV.zip to ./gdelt_data/extracted
# 20181122.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181122.export.CSV.zip to ./gdelt_data\20181122.export.CSV.zip
# Unzipped ./gdelt_data\20181122.export.CSV.zip to ./gdelt_data/extracted
# 20181121.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181121.export.CSV.zip to ./gdelt_data\20181121.export.CSV.zip
# Unzipped ./gdelt_data\20181121.export.CSV.zip to ./gdelt_data/extracted
# 20181120.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181120.export.CSV.zip to ./gdelt_data\20181120.export.CSV.zip
# Unzipped ./gdelt_data\20181120.export.CSV.zip to ./gdelt_data/extracted
# 20181119.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181119.export.CSV.zip to ./gdelt_data\20181119.export.CSV.zip
# Unzipped ./gdelt_data\20181119.export.CSV.zip to ./gdelt_data/extracted
# 20181118.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181118.export.CSV.zip to ./gdelt_data\20181118.export.CSV.zip
# Unzipped ./gdelt_data\20181118.export.CSV.zip to ./gdelt_data/extracted
# 20181117.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181117.export.CSV.zip to ./gdelt_data\20181117.export.CSV.zip
# Unzipped ./gdelt_data\20181117.export.CSV.zip to ./gdelt_data/extracted
# 20181116.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181116.export.CSV.zip to ./gdelt_data\20181116.export.CSV.zip
# Unzipped ./gdelt_data\20181116.export.CSV.zip to ./gdelt_data/extracted
# 20181115.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181115.export.CSV.zip to ./gdelt_data\20181115.export.CSV.zip
# Unzipped ./gdelt_data\20181115.export.CSV.zip to ./gdelt_data/extracted
# 20181114.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181114.export.CSV.zip to ./gdelt_data\20181114.export.CSV.zip
# Unzipped ./gdelt_data\20181114.export.CSV.zip to ./gdelt_data/extracted
# 20181113.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181113.export.CSV.zip to ./gdelt_data\20181113.export.CSV.zip
# Unzipped ./gdelt_data\20181113.export.CSV.zip to ./gdelt_data/extracted
# 20181112.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181112.export.CSV.zip to ./gdelt_data\20181112.export.CSV.zip
# Unzipped ./gdelt_data\20181112.export.CSV.zip to ./gdelt_data/extracted
# 20181111.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181111.export.CSV.zip to ./gdelt_data\20181111.export.CSV.zip
# Unzipped ./gdelt_data\20181111.export.CSV.zip to ./gdelt_data/extracted
# 20181110.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181110.export.CSV.zip to ./gdelt_data\20181110.export.CSV.zip
# Unzipped ./gdelt_data\20181110.export.CSV.zip to ./gdelt_data/extracted
# 20181109.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181109.export.CSV.zip to ./gdelt_data\20181109.export.CSV.zip
# Unzipped ./gdelt_data\20181109.export.CSV.zip to ./gdelt_data/extracted
# 20181108.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181108.export.CSV.zip to ./gdelt_data\20181108.export.CSV.zip
# Unzipped ./gdelt_data\20181108.export.CSV.zip to ./gdelt_data/extracted
# 20181107.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181107.export.CSV.zip to ./gdelt_data\20181107.export.CSV.zip
# Unzipped ./gdelt_data\20181107.export.CSV.zip to ./gdelt_data/extracted
# 20181106.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181106.export.CSV.zip to ./gdelt_data\20181106.export.CSV.zip
# Unzipped ./gdelt_data\20181106.export.CSV.zip to ./gdelt_data/extracted
# 20181105.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181105.export.CSV.zip to ./gdelt_data\20181105.export.CSV.zip
# Unzipped ./gdelt_data\20181105.export.CSV.zip to ./gdelt_data/extracted
# 20181104.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181104.export.CSV.zip to ./gdelt_data\20181104.export.CSV.zip
# Unzipped ./gdelt_data\20181104.export.CSV.zip to ./gdelt_data/extracted
# 20181103.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181103.export.CSV.zip to ./gdelt_data\20181103.export.CSV.zip
# Unzipped ./gdelt_data\20181103.export.CSV.zip to ./gdelt_data/extracted
# 20181102.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181102.export.CSV.zip to ./gdelt_data\20181102.export.CSV.zip
# Unzipped ./gdelt_data\20181102.export.CSV.zip to ./gdelt_data/extracted
# 20181101.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181101.export.CSV.zip to ./gdelt_data\20181101.export.CSV.zip
# Unzipped ./gdelt_data\20181101.export.CSV.zip to ./gdelt_data/extracted
# 20181031.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181031.export.CSV.zip to ./gdelt_data\20181031.export.CSV.zip
# Unzipped ./gdelt_data\20181031.export.CSV.zip to ./gdelt_data/extracted
# 20181030.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181030.export.CSV.zip to ./gdelt_data\20181030.export.CSV.zip
# Unzipped ./gdelt_data\20181030.export.CSV.zip to ./gdelt_data/extracted
# 20181029.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181029.export.CSV.zip to ./gdelt_data\20181029.export.CSV.zip
# Unzipped ./gdelt_data\20181029.export.CSV.zip to ./gdelt_data/extracted
# 20181028.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181028.export.CSV.zip to ./gdelt_data\20181028.export.CSV.zip
# Unzipped ./gdelt_data\20181028.export.CSV.zip to ./gdelt_data/extracted
# 20181027.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181027.export.CSV.zip to ./gdelt_data\20181027.export.CSV.zip
# Unzipped ./gdelt_data\20181027.export.CSV.zip to ./gdelt_data/extracted
# 20181026.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181026.export.CSV.zip to ./gdelt_data\20181026.export.CSV.zip
# Unzipped ./gdelt_data\20181026.export.CSV.zip to ./gdelt_data/extracted
# 20181025.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181025.export.CSV.zip to ./gdelt_data\20181025.export.CSV.zip
# Unzipped ./gdelt_data\20181025.export.CSV.zip to ./gdelt_data/extracted
# 20181024.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181024.export.CSV.zip to ./gdelt_data\20181024.export.CSV.zip
# Unzipped ./gdelt_data\20181024.export.CSV.zip to ./gdelt_data/extracted
# 20181023.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181023.export.CSV.zip to ./gdelt_data\20181023.export.CSV.zip
# Unzipped ./gdelt_data\20181023.export.CSV.zip to ./gdelt_data/extracted
# 20181022.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181022.export.CSV.zip to ./gdelt_data\20181022.export.CSV.zip
# Unzipped ./gdelt_data\20181022.export.CSV.zip to ./gdelt_data/extracted
# 20181021.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181021.export.CSV.zip to ./gdelt_data\20181021.export.CSV.zip
# Unzipped ./gdelt_data\20181021.export.CSV.zip to ./gdelt_data/extracted
# 20181020.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181020.export.CSV.zip to ./gdelt_data\20181020.export.CSV.zip
# Unzipped ./gdelt_data\20181020.export.CSV.zip to ./gdelt_data/extracted
# 20181019.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181019.export.CSV.zip to ./gdelt_data\20181019.export.CSV.zip
# Unzipped ./gdelt_data\20181019.export.CSV.zip to ./gdelt_data/extracted
# 20181018.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181018.export.CSV.zip to ./gdelt_data\20181018.export.CSV.zip
# Unzipped ./gdelt_data\20181018.export.CSV.zip to ./gdelt_data/extracted
# 20181017.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181017.export.CSV.zip to ./gdelt_data\20181017.export.CSV.zip
# Unzipped ./gdelt_data\20181017.export.CSV.zip to ./gdelt_data/extracted
# 20181016.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181016.export.CSV.zip to ./gdelt_data\20181016.export.CSV.zip
# Unzipped ./gdelt_data\20181016.export.CSV.zip to ./gdelt_data/extracted
# 20181015.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181015.export.CSV.zip to ./gdelt_data\20181015.export.CSV.zip
# Unzipped ./gdelt_data\20181015.export.CSV.zip to ./gdelt_data/extracted
# 20181014.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181014.export.CSV.zip to ./gdelt_data\20181014.export.CSV.zip
# Unzipped ./gdelt_data\20181014.export.CSV.zip to ./gdelt_data/extracted
# 20181013.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181013.export.CSV.zip to ./gdelt_data\20181013.export.CSV.zip
# Unzipped ./gdelt_data\20181013.export.CSV.zip to ./gdelt_data/extracted
# 20181012.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181012.export.CSV.zip to ./gdelt_data\20181012.export.CSV.zip
# Unzipped ./gdelt_data\20181012.export.CSV.zip to ./gdelt_data/extracted
# 20181011.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181011.export.CSV.zip to ./gdelt_data\20181011.export.CSV.zip
# Unzipped ./gdelt_data\20181011.export.CSV.zip to ./gdelt_data/extracted
# 20181010.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181010.export.CSV.zip to ./gdelt_data\20181010.export.CSV.zip
# Unzipped ./gdelt_data\20181010.export.CSV.zip to ./gdelt_data/extracted
# 20181009.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181009.export.CSV.zip to ./gdelt_data\20181009.export.CSV.zip
# Unzipped ./gdelt_data\20181009.export.CSV.zip to ./gdelt_data/extracted
# 20181008.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181008.export.CSV.zip to ./gdelt_data\20181008.export.CSV.zip
# Unzipped ./gdelt_data\20181008.export.CSV.zip to ./gdelt_data/extracted
# 20181007.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181007.export.CSV.zip to ./gdelt_data\20181007.export.CSV.zip
# Unzipped ./gdelt_data\20181007.export.CSV.zip to ./gdelt_data/extracted
# 20181006.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181006.export.CSV.zip to ./gdelt_data\20181006.export.CSV.zip
# Unzipped ./gdelt_data\20181006.export.CSV.zip to ./gdelt_data/extracted
# 20181005.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181005.export.CSV.zip to ./gdelt_data\20181005.export.CSV.zip
# Unzipped ./gdelt_data\20181005.export.CSV.zip to ./gdelt_data/extracted
# 20181004.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181004.export.CSV.zip to ./gdelt_data\20181004.export.CSV.zip
# Unzipped ./gdelt_data\20181004.export.CSV.zip to ./gdelt_data/extracted
# 20181003.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181003.export.CSV.zip to ./gdelt_data\20181003.export.CSV.zip
# Unzipped ./gdelt_data\20181003.export.CSV.zip to ./gdelt_data/extracted
# 20181002.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181002.export.CSV.zip to ./gdelt_data\20181002.export.CSV.zip
# Unzipped ./gdelt_data\20181002.export.CSV.zip to ./gdelt_data/extracted
# 20181001.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20181001.export.CSV.zip to ./gdelt_data\20181001.export.CSV.zip
# Unzipped ./gdelt_data\20181001.export.CSV.zip to ./gdelt_data/extracted
# 20180930.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180930.export.CSV.zip to ./gdelt_data\20180930.export.CSV.zip
# Unzipped ./gdelt_data\20180930.export.CSV.zip to ./gdelt_data/extracted
# 20180929.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180929.export.CSV.zip to ./gdelt_data\20180929.export.CSV.zip
# Unzipped ./gdelt_data\20180929.export.CSV.zip to ./gdelt_data/extracted
# 20180928.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180928.export.CSV.zip to ./gdelt_data\20180928.export.CSV.zip
# Unzipped ./gdelt_data\20180928.export.CSV.zip to ./gdelt_data/extracted
# 20180927.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180927.export.CSV.zip to ./gdelt_data\20180927.export.CSV.zip
# Unzipped ./gdelt_data\20180927.export.CSV.zip to ./gdelt_data/extracted
# 20180926.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180926.export.CSV.zip to ./gdelt_data\20180926.export.CSV.zip
# Unzipped ./gdelt_data\20180926.export.CSV.zip to ./gdelt_data/extracted
# 20180925.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180925.export.CSV.zip to ./gdelt_data\20180925.export.CSV.zip
# Unzipped ./gdelt_data\20180925.export.CSV.zip to ./gdelt_data/extracted
# 20180924.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180924.export.CSV.zip to ./gdelt_data\20180924.export.CSV.zip
# Unzipped ./gdelt_data\20180924.export.CSV.zip to ./gdelt_data/extracted
# 20180923.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180923.export.CSV.zip to ./gdelt_data\20180923.export.CSV.zip
# Unzipped ./gdelt_data\20180923.export.CSV.zip to ./gdelt_data/extracted
# 20180922.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180922.export.CSV.zip to ./gdelt_data\20180922.export.CSV.zip
# Unzipped ./gdelt_data\20180922.export.CSV.zip to ./gdelt_data/extracted
# 20180921.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180921.export.CSV.zip to ./gdelt_data\20180921.export.CSV.zip
# Unzipped ./gdelt_data\20180921.export.CSV.zip to ./gdelt_data/extracted
# 20180920.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180920.export.CSV.zip to ./gdelt_data\20180920.export.CSV.zip
# Unzipped ./gdelt_data\20180920.export.CSV.zip to ./gdelt_data/extracted
# 20180919.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180919.export.CSV.zip to ./gdelt_data\20180919.export.CSV.zip
# Unzipped ./gdelt_data\20180919.export.CSV.zip to ./gdelt_data/extracted
# 20180918.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180918.export.CSV.zip to ./gdelt_data\20180918.export.CSV.zip
# Unzipped ./gdelt_data\20180918.export.CSV.zip to ./gdelt_data/extracted
# 20180917.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180917.export.CSV.zip to ./gdelt_data\20180917.export.CSV.zip
# Unzipped ./gdelt_data\20180917.export.CSV.zip to ./gdelt_data/extracted
# 20180916.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180916.export.CSV.zip to ./gdelt_data\20180916.export.CSV.zip
# Unzipped ./gdelt_data\20180916.export.CSV.zip to ./gdelt_data/extracted
# 20180915.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180915.export.CSV.zip to ./gdelt_data\20180915.export.CSV.zip
# Unzipped ./gdelt_data\20180915.export.CSV.zip to ./gdelt_data/extracted
# 20180914.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180914.export.CSV.zip to ./gdelt_data\20180914.export.CSV.zip
# Unzipped ./gdelt_data\20180914.export.CSV.zip to ./gdelt_data/extracted
# 20180913.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180913.export.CSV.zip to ./gdelt_data\20180913.export.CSV.zip
# Unzipped ./gdelt_data\20180913.export.CSV.zip to ./gdelt_data/extracted
# 20180912.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180912.export.CSV.zip to ./gdelt_data\20180912.export.CSV.zip
# Unzipped ./gdelt_data\20180912.export.CSV.zip to ./gdelt_data/extracted
# 20180911.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180911.export.CSV.zip to ./gdelt_data\20180911.export.CSV.zip
# Unzipped ./gdelt_data\20180911.export.CSV.zip to ./gdelt_data/extracted
# 20180910.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180910.export.CSV.zip to ./gdelt_data\20180910.export.CSV.zip
# Unzipped ./gdelt_data\20180910.export.CSV.zip to ./gdelt_data/extracted
# 20180909.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180909.export.CSV.zip to ./gdelt_data\20180909.export.CSV.zip
# Unzipped ./gdelt_data\20180909.export.CSV.zip to ./gdelt_data/extracted
# 20180908.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180908.export.CSV.zip to ./gdelt_data\20180908.export.CSV.zip
# Unzipped ./gdelt_data\20180908.export.CSV.zip to ./gdelt_data/extracted
# 20180907.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180907.export.CSV.zip to ./gdelt_data\20180907.export.CSV.zip
# Unzipped ./gdelt_data\20180907.export.CSV.zip to ./gdelt_data/extracted
# 20180906.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180906.export.CSV.zip to ./gdelt_data\20180906.export.CSV.zip
# Unzipped ./gdelt_data\20180906.export.CSV.zip to ./gdelt_data/extracted
# 20180905.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180905.export.CSV.zip to ./gdelt_data\20180905.export.CSV.zip
# Unzipped ./gdelt_data\20180905.export.CSV.zip to ./gdelt_data/extracted
# 20180904.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180904.export.CSV.zip to ./gdelt_data\20180904.export.CSV.zip
# Unzipped ./gdelt_data\20180904.export.CSV.zip to ./gdelt_data/extracted
# 20180903.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180903.export.CSV.zip to ./gdelt_data\20180903.export.CSV.zip
# Unzipped ./gdelt_data\20180903.export.CSV.zip to ./gdelt_data/extracted
# 20180902.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180902.export.CSV.zip to ./gdelt_data\20180902.export.CSV.zip
# Unzipped ./gdelt_data\20180902.export.CSV.zip to ./gdelt_data/extracted
# 20180901.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180901.export.CSV.zip to ./gdelt_data\20180901.export.CSV.zip
# Unzipped ./gdelt_data\20180901.export.CSV.zip to ./gdelt_data/extracted
# 20180831.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180831.export.CSV.zip to ./gdelt_data\20180831.export.CSV.zip
# Unzipped ./gdelt_data\20180831.export.CSV.zip to ./gdelt_data/extracted
# 20180830.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180830.export.CSV.zip to ./gdelt_data\20180830.export.CSV.zip
# Unzipped ./gdelt_data\20180830.export.CSV.zip to ./gdelt_data/extracted
# 20180829.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180829.export.CSV.zip to ./gdelt_data\20180829.export.CSV.zip
# Unzipped ./gdelt_data\20180829.export.CSV.zip to ./gdelt_data/extracted
# 20180828.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180828.export.CSV.zip to ./gdelt_data\20180828.export.CSV.zip
# Unzipped ./gdelt_data\20180828.export.CSV.zip to ./gdelt_data/extracted
# 20180827.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180827.export.CSV.zip to ./gdelt_data\20180827.export.CSV.zip
# Unzipped ./gdelt_data\20180827.export.CSV.zip to ./gdelt_data/extracted
# 20180826.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180826.export.CSV.zip to ./gdelt_data\20180826.export.CSV.zip
# Unzipped ./gdelt_data\20180826.export.CSV.zip to ./gdelt_data/extracted
# 20180825.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180825.export.CSV.zip to ./gdelt_data\20180825.export.CSV.zip
# Unzipped ./gdelt_data\20180825.export.CSV.zip to ./gdelt_data/extracted
# 20180824.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180824.export.CSV.zip to ./gdelt_data\20180824.export.CSV.zip
# Unzipped ./gdelt_data\20180824.export.CSV.zip to ./gdelt_data/extracted
# 20180823.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180823.export.CSV.zip to ./gdelt_data\20180823.export.CSV.zip
# Unzipped ./gdelt_data\20180823.export.CSV.zip to ./gdelt_data/extracted
# 20180822.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180822.export.CSV.zip to ./gdelt_data\20180822.export.CSV.zip
# Unzipped ./gdelt_data\20180822.export.CSV.zip to ./gdelt_data/extracted
# 20180821.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180821.export.CSV.zip to ./gdelt_data\20180821.export.CSV.zip
# Unzipped ./gdelt_data\20180821.export.CSV.zip to ./gdelt_data/extracted
# 20180820.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180820.export.CSV.zip to ./gdelt_data\20180820.export.CSV.zip
# Unzipped ./gdelt_data\20180820.export.CSV.zip to ./gdelt_data/extracted
# 20180819.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180819.export.CSV.zip to ./gdelt_data\20180819.export.CSV.zip
# Unzipped ./gdelt_data\20180819.export.CSV.zip to ./gdelt_data/extracted
# 20180818.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180818.export.CSV.zip to ./gdelt_data\20180818.export.CSV.zip
# Unzipped ./gdelt_data\20180818.export.CSV.zip to ./gdelt_data/extracted
# 20180817.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180817.export.CSV.zip to ./gdelt_data\20180817.export.CSV.zip
# Unzipped ./gdelt_data\20180817.export.CSV.zip to ./gdelt_data/extracted
# 20180816.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180816.export.CSV.zip to ./gdelt_data\20180816.export.CSV.zip
# Unzipped ./gdelt_data\20180816.export.CSV.zip to ./gdelt_data/extracted
# 20180815.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180815.export.CSV.zip to ./gdelt_data\20180815.export.CSV.zip
# Unzipped ./gdelt_data\20180815.export.CSV.zip to ./gdelt_data/extracted
# 20180814.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180814.export.CSV.zip to ./gdelt_data\20180814.export.CSV.zip
# Unzipped ./gdelt_data\20180814.export.CSV.zip to ./gdelt_data/extracted
# 20180813.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180813.export.CSV.zip to ./gdelt_data\20180813.export.CSV.zip
# Unzipped ./gdelt_data\20180813.export.CSV.zip to ./gdelt_data/extracted
# 20180812.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180812.export.CSV.zip to ./gdelt_data\20180812.export.CSV.zip
# Unzipped ./gdelt_data\20180812.export.CSV.zip to ./gdelt_data/extracted
# 20180811.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180811.export.CSV.zip to ./gdelt_data\20180811.export.CSV.zip
# Unzipped ./gdelt_data\20180811.export.CSV.zip to ./gdelt_data/extracted
# 20180810.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180810.export.CSV.zip to ./gdelt_data\20180810.export.CSV.zip
# Unzipped ./gdelt_data\20180810.export.CSV.zip to ./gdelt_data/extracted
# 20180809.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180809.export.CSV.zip to ./gdelt_data\20180809.export.CSV.zip
# Unzipped ./gdelt_data\20180809.export.CSV.zip to ./gdelt_data/extracted
# 20180808.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180808.export.CSV.zip to ./gdelt_data\20180808.export.CSV.zip
# Unzipped ./gdelt_data\20180808.export.CSV.zip to ./gdelt_data/extracted
# 20180807.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180807.export.CSV.zip to ./gdelt_data\20180807.export.CSV.zip
# Unzipped ./gdelt_data\20180807.export.CSV.zip to ./gdelt_data/extracted
# 20180806.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180806.export.CSV.zip to ./gdelt_data\20180806.export.CSV.zip
# Unzipped ./gdelt_data\20180806.export.CSV.zip to ./gdelt_data/extracted
# 20180805.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180805.export.CSV.zip to ./gdelt_data\20180805.export.CSV.zip
# Unzipped ./gdelt_data\20180805.export.CSV.zip to ./gdelt_data/extracted
# 20180804.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180804.export.CSV.zip to ./gdelt_data\20180804.export.CSV.zip
# Unzipped ./gdelt_data\20180804.export.CSV.zip to ./gdelt_data/extracted
# 20180803.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180803.export.CSV.zip to ./gdelt_data\20180803.export.CSV.zip
# Unzipped ./gdelt_data\20180803.export.CSV.zip to ./gdelt_data/extracted
# 20180802.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180802.export.CSV.zip to ./gdelt_data\20180802.export.CSV.zip
# Unzipped ./gdelt_data\20180802.export.CSV.zip to ./gdelt_data/extracted
# 20180801.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180801.export.CSV.zip to ./gdelt_data\20180801.export.CSV.zip
# Unzipped ./gdelt_data\20180801.export.CSV.zip to ./gdelt_data/extracted
# 20180731.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180731.export.CSV.zip to ./gdelt_data\20180731.export.CSV.zip
# Unzipped ./gdelt_data\20180731.export.CSV.zip to ./gdelt_data/extracted
# 20180730.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180730.export.CSV.zip to ./gdelt_data\20180730.export.CSV.zip
# Unzipped ./gdelt_data\20180730.export.CSV.zip to ./gdelt_data/extracted
# 20180729.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180729.export.CSV.zip to ./gdelt_data\20180729.export.CSV.zip
# Unzipped ./gdelt_data\20180729.export.CSV.zip to ./gdelt_data/extracted
# 20180728.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180728.export.CSV.zip to ./gdelt_data\20180728.export.CSV.zip
# Unzipped ./gdelt_data\20180728.export.CSV.zip to ./gdelt_data/extracted
# 20180727.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180727.export.CSV.zip to ./gdelt_data\20180727.export.CSV.zip
# Unzipped ./gdelt_data\20180727.export.CSV.zip to ./gdelt_data/extracted
# 20180726.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180726.export.CSV.zip to ./gdelt_data\20180726.export.CSV.zip
# Unzipped ./gdelt_data\20180726.export.CSV.zip to ./gdelt_data/extracted
# 20180725.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180725.export.CSV.zip to ./gdelt_data\20180725.export.CSV.zip
# Unzipped ./gdelt_data\20180725.export.CSV.zip to ./gdelt_data/extracted
# 20180724.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180724.export.CSV.zip to ./gdelt_data\20180724.export.CSV.zip
# Unzipped ./gdelt_data\20180724.export.CSV.zip to ./gdelt_data/extracted
# 20180723.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180723.export.CSV.zip to ./gdelt_data\20180723.export.CSV.zip
# Unzipped ./gdelt_data\20180723.export.CSV.zip to ./gdelt_data/extracted
# 20180722.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180722.export.CSV.zip to ./gdelt_data\20180722.export.CSV.zip
# Unzipped ./gdelt_data\20180722.export.CSV.zip to ./gdelt_data/extracted
# 20180721.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180721.export.CSV.zip to ./gdelt_data\20180721.export.CSV.zip
# Unzipped ./gdelt_data\20180721.export.CSV.zip to ./gdelt_data/extracted
# 20180720.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180720.export.CSV.zip to ./gdelt_data\20180720.export.CSV.zip
# Unzipped ./gdelt_data\20180720.export.CSV.zip to ./gdelt_data/extracted
# 20180719.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180719.export.CSV.zip to ./gdelt_data\20180719.export.CSV.zip
# Unzipped ./gdelt_data\20180719.export.CSV.zip to ./gdelt_data/extracted
# 20180718.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180718.export.CSV.zip to ./gdelt_data\20180718.export.CSV.zip
# Unzipped ./gdelt_data\20180718.export.CSV.zip to ./gdelt_data/extracted
# 20180717.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180717.export.CSV.zip to ./gdelt_data\20180717.export.CSV.zip
# Unzipped ./gdelt_data\20180717.export.CSV.zip to ./gdelt_data/extracted
# 20180716.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180716.export.CSV.zip to ./gdelt_data\20180716.export.CSV.zip
# Unzipped ./gdelt_data\20180716.export.CSV.zip to ./gdelt_data/extracted
# 20180715.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180715.export.CSV.zip to ./gdelt_data\20180715.export.CSV.zip
# Unzipped ./gdelt_data\20180715.export.CSV.zip to ./gdelt_data/extracted
# 20180714.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180714.export.CSV.zip to ./gdelt_data\20180714.export.CSV.zip
# Unzipped ./gdelt_data\20180714.export.CSV.zip to ./gdelt_data/extracted
# 20180713.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180713.export.CSV.zip to ./gdelt_data\20180713.export.CSV.zip
# Unzipped ./gdelt_data\20180713.export.CSV.zip to ./gdelt_data/extracted
# 20180712.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180712.export.CSV.zip to ./gdelt_data\20180712.export.CSV.zip
# Unzipped ./gdelt_data\20180712.export.CSV.zip to ./gdelt_data/extracted
# 20180711.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180711.export.CSV.zip to ./gdelt_data\20180711.export.CSV.zip
# Unzipped ./gdelt_data\20180711.export.CSV.zip to ./gdelt_data/extracted
# 20180710.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180710.export.CSV.zip to ./gdelt_data\20180710.export.CSV.zip
# Unzipped ./gdelt_data\20180710.export.CSV.zip to ./gdelt_data/extracted
# 20180709.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180709.export.CSV.zip to ./gdelt_data\20180709.export.CSV.zip
# Unzipped ./gdelt_data\20180709.export.CSV.zip to ./gdelt_data/extracted
# 20180708.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180708.export.CSV.zip to ./gdelt_data\20180708.export.CSV.zip
# Unzipped ./gdelt_data\20180708.export.CSV.zip to ./gdelt_data/extracted
# 20180707.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180707.export.CSV.zip to ./gdelt_data\20180707.export.CSV.zip
# Unzipped ./gdelt_data\20180707.export.CSV.zip to ./gdelt_data/extracted
# 20180706.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180706.export.CSV.zip to ./gdelt_data\20180706.export.CSV.zip
# Unzipped ./gdelt_data\20180706.export.CSV.zip to ./gdelt_data/extracted
# 20180705.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180705.export.CSV.zip to ./gdelt_data\20180705.export.CSV.zip
# Unzipped ./gdelt_data\20180705.export.CSV.zip to ./gdelt_data/extracted
# 20180704.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180704.export.CSV.zip to ./gdelt_data\20180704.export.CSV.zip
# Unzipped ./gdelt_data\20180704.export.CSV.zip to ./gdelt_data/extracted
# 20180703.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180703.export.CSV.zip to ./gdelt_data\20180703.export.CSV.zip
# Unzipped ./gdelt_data\20180703.export.CSV.zip to ./gdelt_data/extracted
# 20180702.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180702.export.CSV.zip to ./gdelt_data\20180702.export.CSV.zip
# Unzipped ./gdelt_data\20180702.export.CSV.zip to ./gdelt_data/extracted
# 20180701.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180701.export.CSV.zip to ./gdelt_data\20180701.export.CSV.zip
# Unzipped ./gdelt_data\20180701.export.CSV.zip to ./gdelt_data/extracted
# 20180630.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180630.export.CSV.zip to ./gdelt_data\20180630.export.CSV.zip
# Unzipped ./gdelt_data\20180630.export.CSV.zip to ./gdelt_data/extracted
# 20180629.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180629.export.CSV.zip to ./gdelt_data\20180629.export.CSV.zip
# Unzipped ./gdelt_data\20180629.export.CSV.zip to ./gdelt_data/extracted
# 20180628.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180628.export.CSV.zip to ./gdelt_data\20180628.export.CSV.zip
# Unzipped ./gdelt_data\20180628.export.CSV.zip to ./gdelt_data/extracted
# 20180627.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180627.export.CSV.zip to ./gdelt_data\20180627.export.CSV.zip
# Unzipped ./gdelt_data\20180627.export.CSV.zip to ./gdelt_data/extracted
# 20180626.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180626.export.CSV.zip to ./gdelt_data\20180626.export.CSV.zip
# Unzipped ./gdelt_data\20180626.export.CSV.zip to ./gdelt_data/extracted
# 20180625.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180625.export.CSV.zip to ./gdelt_data\20180625.export.CSV.zip
# Unzipped ./gdelt_data\20180625.export.CSV.zip to ./gdelt_data/extracted
# 20180624.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180624.export.CSV.zip to ./gdelt_data\20180624.export.CSV.zip
# Unzipped ./gdelt_data\20180624.export.CSV.zip to ./gdelt_data/extracted
# 20180623.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180623.export.CSV.zip to ./gdelt_data\20180623.export.CSV.zip
# Unzipped ./gdelt_data\20180623.export.CSV.zip to ./gdelt_data/extracted
# 20180622.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180622.export.CSV.zip to ./gdelt_data\20180622.export.CSV.zip
# Unzipped ./gdelt_data\20180622.export.CSV.zip to ./gdelt_data/extracted
# 20180621.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180621.export.CSV.zip to ./gdelt_data\20180621.export.CSV.zip
# Unzipped ./gdelt_data\20180621.export.CSV.zip to ./gdelt_data/extracted
# 20180620.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180620.export.CSV.zip to ./gdelt_data\20180620.export.CSV.zip
# Unzipped ./gdelt_data\20180620.export.CSV.zip to ./gdelt_data/extracted
# 20180619.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180619.export.CSV.zip to ./gdelt_data\20180619.export.CSV.zip
# Unzipped ./gdelt_data\20180619.export.CSV.zip to ./gdelt_data/extracted
# 20180618.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180618.export.CSV.zip to ./gdelt_data\20180618.export.CSV.zip
# Unzipped ./gdelt_data\20180618.export.CSV.zip to ./gdelt_data/extracted
# 20180617.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180617.export.CSV.zip to ./gdelt_data\20180617.export.CSV.zip
# Unzipped ./gdelt_data\20180617.export.CSV.zip to ./gdelt_data/extracted
# 20180616.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180616.export.CSV.zip to ./gdelt_data\20180616.export.CSV.zip
# Unzipped ./gdelt_data\20180616.export.CSV.zip to ./gdelt_data/extracted
# 20180615.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180615.export.CSV.zip to ./gdelt_data\20180615.export.CSV.zip
# Unzipped ./gdelt_data\20180615.export.CSV.zip to ./gdelt_data/extracted
# 20180614.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180614.export.CSV.zip to ./gdelt_data\20180614.export.CSV.zip
# Unzipped ./gdelt_data\20180614.export.CSV.zip to ./gdelt_data/extracted
# 20180613.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180613.export.CSV.zip to ./gdelt_data\20180613.export.CSV.zip
# Unzipped ./gdelt_data\20180613.export.CSV.zip to ./gdelt_data/extracted
# 20180612.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180612.export.CSV.zip to ./gdelt_data\20180612.export.CSV.zip
# Unzipped ./gdelt_data\20180612.export.CSV.zip to ./gdelt_data/extracted
# 20180611.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180611.export.CSV.zip to ./gdelt_data\20180611.export.CSV.zip
# Unzipped ./gdelt_data\20180611.export.CSV.zip to ./gdelt_data/extracted
# 20180610.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180610.export.CSV.zip to ./gdelt_data\20180610.export.CSV.zip
# Unzipped ./gdelt_data\20180610.export.CSV.zip to ./gdelt_data/extracted
# 20180609.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180609.export.CSV.zip to ./gdelt_data\20180609.export.CSV.zip
# Unzipped ./gdelt_data\20180609.export.CSV.zip to ./gdelt_data/extracted
# 20180608.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180608.export.CSV.zip to ./gdelt_data\20180608.export.CSV.zip
# Unzipped ./gdelt_data\20180608.export.CSV.zip to ./gdelt_data/extracted
# 20180607.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180607.export.CSV.zip to ./gdelt_data\20180607.export.CSV.zip
# Unzipped ./gdelt_data\20180607.export.CSV.zip to ./gdelt_data/extracted
# 20180606.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180606.export.CSV.zip to ./gdelt_data\20180606.export.CSV.zip
# Unzipped ./gdelt_data\20180606.export.CSV.zip to ./gdelt_data/extracted
# 20180605.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180605.export.CSV.zip to ./gdelt_data\20180605.export.CSV.zip
# Unzipped ./gdelt_data\20180605.export.CSV.zip to ./gdelt_data/extracted
# 20180604.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180604.export.CSV.zip to ./gdelt_data\20180604.export.CSV.zip
# Unzipped ./gdelt_data\20180604.export.CSV.zip to ./gdelt_data/extracted
# 20180603.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180603.export.CSV.zip to ./gdelt_data\20180603.export.CSV.zip
# Unzipped ./gdelt_data\20180603.export.CSV.zip to ./gdelt_data/extracted
# 20180602.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180602.export.CSV.zip to ./gdelt_data\20180602.export.CSV.zip
# Unzipped ./gdelt_data\20180602.export.CSV.zip to ./gdelt_data/extracted
# 20180601.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180601.export.CSV.zip to ./gdelt_data\20180601.export.CSV.zip
# Unzipped ./gdelt_data\20180601.export.CSV.zip to ./gdelt_data/extracted
# 20180531.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180531.export.CSV.zip to ./gdelt_data\20180531.export.CSV.zip
# Unzipped ./gdelt_data\20180531.export.CSV.zip to ./gdelt_data/extracted
# 20180530.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180530.export.CSV.zip to ./gdelt_data\20180530.export.CSV.zip
# Unzipped ./gdelt_data\20180530.export.CSV.zip to ./gdelt_data/extracted
# 20180529.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180529.export.CSV.zip to ./gdelt_data\20180529.export.CSV.zip
# Unzipped ./gdelt_data\20180529.export.CSV.zip to ./gdelt_data/extracted
# 20180528.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180528.export.CSV.zip to ./gdelt_data\20180528.export.CSV.zip
# Unzipped ./gdelt_data\20180528.export.CSV.zip to ./gdelt_data/extracted
# 20180527.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180527.export.CSV.zip to ./gdelt_data\20180527.export.CSV.zip
# Unzipped ./gdelt_data\20180527.export.CSV.zip to ./gdelt_data/extracted
# 20180526.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180526.export.CSV.zip to ./gdelt_data\20180526.export.CSV.zip
# Unzipped ./gdelt_data\20180526.export.CSV.zip to ./gdelt_data/extracted
# 20180525.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180525.export.CSV.zip to ./gdelt_data\20180525.export.CSV.zip
# Unzipped ./gdelt_data\20180525.export.CSV.zip to ./gdelt_data/extracted
# 20180524.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180524.export.CSV.zip to ./gdelt_data\20180524.export.CSV.zip
# Unzipped ./gdelt_data\20180524.export.CSV.zip to ./gdelt_data/extracted
# 20180523.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180523.export.CSV.zip to ./gdelt_data\20180523.export.CSV.zip
# Unzipped ./gdelt_data\20180523.export.CSV.zip to ./gdelt_data/extracted
# 20180522.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180522.export.CSV.zip to ./gdelt_data\20180522.export.CSV.zip
# Unzipped ./gdelt_data\20180522.export.CSV.zip to ./gdelt_data/extracted
# 20180521.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180521.export.CSV.zip to ./gdelt_data\20180521.export.CSV.zip
# Unzipped ./gdelt_data\20180521.export.CSV.zip to ./gdelt_data/extracted
# 20180520.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180520.export.CSV.zip to ./gdelt_data\20180520.export.CSV.zip
# Unzipped ./gdelt_data\20180520.export.CSV.zip to ./gdelt_data/extracted
# 20180519.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180519.export.CSV.zip to ./gdelt_data\20180519.export.CSV.zip
# Unzipped ./gdelt_data\20180519.export.CSV.zip to ./gdelt_data/extracted
# 20180518.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180518.export.CSV.zip to ./gdelt_data\20180518.export.CSV.zip
# Unzipped ./gdelt_data\20180518.export.CSV.zip to ./gdelt_data/extracted
# 20180517.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180517.export.CSV.zip to ./gdelt_data\20180517.export.CSV.zip
# Unzipped ./gdelt_data\20180517.export.CSV.zip to ./gdelt_data/extracted
# 20180516.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180516.export.CSV.zip to ./gdelt_data\20180516.export.CSV.zip
# Unzipped ./gdelt_data\20180516.export.CSV.zip to ./gdelt_data/extracted
# 20180515.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180515.export.CSV.zip to ./gdelt_data\20180515.export.CSV.zip
# Unzipped ./gdelt_data\20180515.export.CSV.zip to ./gdelt_data/extracted
# 20180514.export.CSV.zip
# ...
# 20180218.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180218.export.CSV.zip to ./gdelt_data\20180218.export.CSV.zip
# Unzipped ./gdelt_data\20180218.export.CSV.zip to ./gdelt_data/extracted
# 20180217.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180217.export.CSV.zip to ./gdelt_data\20180217.export.CSV.zip
# Unzipped ./gdelt_data\20180217.export.CSV.zip to ./gdelt_data/extracted
# 20180216.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180216.export.CSV.zip to ./gdelt_data\20180216.export.CSV.zip
# Unzipped ./gdelt_data\20180216.export.CSV.zip to ./gdelt_data/extracted
# 20180215.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180215.export.CSV.zip to ./gdelt_data\20180215.export.CSV.zip
# Unzipped ./gdelt_data\20180215.export.CSV.zip to ./gdelt_data/extracted
# 20180214.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180214.export.CSV.zip to ./gdelt_data\20180214.export.CSV.zip
# Unzipped ./gdelt_data\20180214.export.CSV.zip to ./gdelt_data/extracted
# 20180213.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180213.export.CSV.zip to ./gdelt_data\20180213.export.CSV.zip
# Unzipped ./gdelt_data\20180213.export.CSV.zip to ./gdelt_data/extracted
# 20180212.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180212.export.CSV.zip to ./gdelt_data\20180212.export.CSV.zip
# Unzipped ./gdelt_data\20180212.export.CSV.zip to ./gdelt_data/extracted
# 20180211.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180211.export.CSV.zip to ./gdelt_data\20180211.export.CSV.zip
# Unzipped ./gdelt_data\20180211.export.CSV.zip to ./gdelt_data/extracted
# 20180210.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180210.export.CSV.zip to ./gdelt_data\20180210.export.CSV.zip
# Unzipped ./gdelt_data\20180210.export.CSV.zip to ./gdelt_data/extracted
# 20180209.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180209.export.CSV.zip to ./gdelt_data\20180209.export.CSV.zip
# Unzipped ./gdelt_data\20180209.export.CSV.zip to ./gdelt_data/extracted
# 20180208.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180208.export.CSV.zip to ./gdelt_data\20180208.export.CSV.zip
# Unzipped ./gdelt_data\20180208.export.CSV.zip to ./gdelt_data/extracted
# 20180207.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180207.export.CSV.zip to ./gdelt_data\20180207.export.CSV.zip
# Unzipped ./gdelt_data\20180207.export.CSV.zip to ./gdelt_data/extracted
# 20180206.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180206.export.CSV.zip to ./gdelt_data\20180206.export.CSV.zip
# Unzipped ./gdelt_data\20180206.export.CSV.zip to ./gdelt_data/extracted
# 20180205.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180205.export.CSV.zip to ./gdelt_data\20180205.export.CSV.zip
# Unzipped ./gdelt_data\20180205.export.CSV.zip to ./gdelt_data/extracted
# 20180204.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180204.export.CSV.zip to ./gdelt_data\20180204.export.CSV.zip
# Unzipped ./gdelt_data\20180204.export.CSV.zip to ./gdelt_data/extracted
# 20180203.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180203.export.CSV.zip to ./gdelt_data\20180203.export.CSV.zip
# Unzipped ./gdelt_data\20180203.export.CSV.zip to ./gdelt_data/extracted
# 20180202.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180202.export.CSV.zip to ./gdelt_data\20180202.export.CSV.zip
# Unzipped ./gdelt_data\20180202.export.CSV.zip to ./gdelt_data/extracted
# 20180201.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180201.export.CSV.zip to ./gdelt_data\20180201.export.CSV.zip
# Unzipped ./gdelt_data\20180201.export.CSV.zip to ./gdelt_data/extracted
# 20180131.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180131.export.CSV.zip to ./gdelt_data\20180131.export.CSV.zip
# Unzipped ./gdelt_data\20180131.export.CSV.zip to ./gdelt_data/extracted
# 20180130.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180130.export.CSV.zip to ./gdelt_data\20180130.export.CSV.zip
# Unzipped ./gdelt_data\20180130.export.CSV.zip to ./gdelt_data/extracted
# 20180129.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180129.export.CSV.zip to ./gdelt_data\20180129.export.CSV.zip
# Unzipped ./gdelt_data\20180129.export.CSV.zip to ./gdelt_data/extracted
# 20180128.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180128.export.CSV.zip to ./gdelt_data\20180128.export.CSV.zip
# Unzipped ./gdelt_data\20180128.export.CSV.zip to ./gdelt_data/extracted
# 20180127.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180127.export.CSV.zip to ./gdelt_data\20180127.export.CSV.zip
# Unzipped ./gdelt_data\20180127.export.CSV.zip to ./gdelt_data/extracted
# 20180126.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180126.export.CSV.zip to ./gdelt_data\20180126.export.CSV.zip
# Unzipped ./gdelt_data\20180126.export.CSV.zip to ./gdelt_data/extracted
# 20180125.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180125.export.CSV.zip to ./gdelt_data\20180125.export.CSV.zip
# Unzipped ./gdelt_data\20180125.export.CSV.zip to ./gdelt_data/extracted
# 20180124.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180124.export.CSV.zip to ./gdelt_data\20180124.export.CSV.zip
# Unzipped ./gdelt_data\20180124.export.CSV.zip to ./gdelt_data/extracted
# 20180123.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180123.export.CSV.zip to ./gdelt_data\20180123.export.CSV.zip
# Unzipped ./gdelt_data\20180123.export.CSV.zip to ./gdelt_data/extracted
# 20180122.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180122.export.CSV.zip to ./gdelt_data\20180122.export.CSV.zip
# Unzipped ./gdelt_data\20180122.export.CSV.zip to ./gdelt_data/extracted
# 20180121.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180121.export.CSV.zip to ./gdelt_data\20180121.export.CSV.zip
# Unzipped ./gdelt_data\20180121.export.CSV.zip to ./gdelt_data/extracted
# 20180120.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180120.export.CSV.zip to ./gdelt_data\20180120.export.CSV.zip
# Unzipped ./gdelt_data\20180120.export.CSV.zip to ./gdelt_data/extracted
# 20180119.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180119.export.CSV.zip to ./gdelt_data\20180119.export.CSV.zip
# Unzipped ./gdelt_data\20180119.export.CSV.zip to ./gdelt_data/extracted
# 20180118.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180118.export.CSV.zip to ./gdelt_data\20180118.export.CSV.zip
# Unzipped ./gdelt_data\20180118.export.CSV.zip to ./gdelt_data/extracted
# 20180117.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180117.export.CSV.zip to ./gdelt_data\20180117.export.CSV.zip
# Unzipped ./gdelt_data\20180117.export.CSV.zip to ./gdelt_data/extracted
# 20180116.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180116.export.CSV.zip to ./gdelt_data\20180116.export.CSV.zip
# Unzipped ./gdelt_data\20180116.export.CSV.zip to ./gdelt_data/extracted
# 20180115.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180115.export.CSV.zip to ./gdelt_data\20180115.export.CSV.zip
# Unzipped ./gdelt_data\20180115.export.CSV.zip to ./gdelt_data/extracted
# 20180114.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180114.export.CSV.zip to ./gdelt_data\20180114.export.CSV.zip
# Unzipped ./gdelt_data\20180114.export.CSV.zip to ./gdelt_data/extracted
# 20180113.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180113.export.CSV.zip to ./gdelt_data\20180113.export.CSV.zip
# Unzipped ./gdelt_data\20180113.export.CSV.zip to ./gdelt_data/extracted
# 20180112.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180112.export.CSV.zip to ./gdelt_data\20180112.export.CSV.zip
# Unzipped ./gdelt_data\20180112.export.CSV.zip to ./gdelt_data/extracted
# 20180111.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180111.export.CSV.zip to ./gdelt_data\20180111.export.CSV.zip
# Unzipped ./gdelt_data\20180111.export.CSV.zip to ./gdelt_data/extracted
# 20180110.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180110.export.CSV.zip to ./gdelt_data\20180110.export.CSV.zip
# Unzipped ./gdelt_data\20180110.export.CSV.zip to ./gdelt_data/extracted
# 20180109.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180109.export.CSV.zip to ./gdelt_data\20180109.export.CSV.zip
# Unzipped ./gdelt_data\20180109.export.CSV.zip to ./gdelt_data/extracted
# 20180108.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180108.export.CSV.zip to ./gdelt_data\20180108.export.CSV.zip
# Unzipped ./gdelt_data\20180108.export.CSV.zip to ./gdelt_data/extracted
# 20180107.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180107.export.CSV.zip to ./gdelt_data\20180107.export.CSV.zip
# Unzipped ./gdelt_data\20180107.export.CSV.zip to ./gdelt_data/extracted
# 20180106.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180106.export.CSV.zip to ./gdelt_data\20180106.export.CSV.zip
# Unzipped ./gdelt_data\20180106.export.CSV.zip to ./gdelt_data/extracted
# 20180105.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180105.export.CSV.zip to ./gdelt_data\20180105.export.CSV.zip
# Unzipped ./gdelt_data\20180105.export.CSV.zip to ./gdelt_data/extracted
# 20180104.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180104.export.CSV.zip to ./gdelt_data\20180104.export.CSV.zip
# Unzipped ./gdelt_data\20180104.export.CSV.zip to ./gdelt_data/extracted
# 20180103.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180103.export.CSV.zip to ./gdelt_data\20180103.export.CSV.zip
# Unzipped ./gdelt_data\20180103.export.CSV.zip to ./gdelt_data/extracted
# 20180102.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180102.export.CSV.zip to ./gdelt_data\20180102.export.CSV.zip
# Unzipped ./gdelt_data\20180102.export.CSV.zip to ./gdelt_data/extracted
# 20180101.export.CSV.zip
# Downloaded http://data.gdeltproject.org/events/20180101.export.CSV.zip to ./gdelt_data\20180101.export.CSV.zip
# Unzipped ./gdelt_data\20180101.export.CSV.zip to ./gdelt_data/extracted
# Skipping file with invalid date format: 201303.zip
# Skipping file with invalid date format: 201302.zip
# Skipping file with invalid date format: 201301.zip
# Skipping file with invalid date format: 201212.zip
# Skipping file with invalid date format: 201211.zip
# Skipping file with invalid date format: 201210.zip
# Skipping file with invalid date format: 201209.zip
# Skipping file with invalid date format: 201208.zip
# Skipping file with invalid date format: 201207.zip
# Skipping file with invalid date format: 201206.zip
# Skipping file with invalid date format: 201205.zip
# Skipping file with invalid date format: 201204.zip
# Skipping file with invalid date format: 201203.zip
# Skipping file with invalid date format: 201202.zip
# Skipping file with invalid date format: 201201.zip
# Skipping file with invalid date format: 201112.zip
# Skipping file with invalid date format: 201111.zip
# Skipping file with invalid date format: 201110.zip
# Skipping file with invalid date format: 201109.zip
# Skipping file with invalid date format: 201108.zip
# Skipping file with invalid date format: 201107.zip
# Skipping file with invalid date format: 201106.zip
# Skipping file with invalid date format: 201105.zip
# Skipping file with invalid date format: 201104.zip
# Skipping file with invalid date format: 201103.zip
# Skipping file with invalid date format: 201102.zip
# Skipping file with invalid date format: 201101.zip
# Skipping file with invalid date format: 201012.zip
# Skipping file with invalid date format: 201011.zip
# Skipping file with invalid date format: 201010.zip
# Skipping file with invalid date format: 201009.zip
# Skipping file with invalid date format: 201008.zip
# Skipping file with invalid date format: 201007.zip
# Skipping file with invalid date format: 201006.zip
# Skipping file with invalid date format: 201005.zip
# Skipping file with invalid date format: 201004.zip
# Skipping file with invalid date format: 201003.zip
# Skipping file with invalid date format: 201002.zip
# Skipping file with invalid date format: 201001.zip
# Skipping file with invalid date format: 200912.zip
# Skipping file with invalid date format: 200911.zip
# Skipping file with invalid date format: 200910.zip
# Skipping file with invalid date format: 200909.zip
# Skipping file with invalid date format: 200908.zip
# Skipping file with invalid date format: 200907.zip
# Skipping file with invalid date format: 200906.zip
# Skipping file with invalid date format: 200905.zip
# Skipping file with invalid date format: 200904.zip
# Skipping file with invalid date format: 200903.zip
# Skipping file with invalid date format: 200902.zip
# Skipping file with invalid date format: 200901.zip
# Skipping file with invalid date format: 200812.zip
# Skipping file with invalid date format: 200811.zip
# Skipping file with invalid date format: 200810.zip
# Skipping file with invalid date format: 200809.zip
# Skipping file with invalid date format: 200808.zip
# Skipping file with invalid date format: 200807.zip
# Skipping file with invalid date format: 200806.zip
# Skipping file with invalid date format: 200805.zip
# Skipping file with invalid date format: 200804.zip
# Skipping file with invalid date format: 200803.zip
# Skipping file with invalid date format: 200802.zip
# Skipping file with invalid date format: 200801.zip
# Skipping file with invalid date format: 200712.zip
# Skipping file with invalid date format: 200711.zip
# Skipping file with invalid date format: 200710.zip
# Skipping file with invalid date format: 200709.zip
# Skipping file with invalid date format: 200708.zip
# Skipping file with invalid date format: 200707.zip
# Skipping file with invalid date format: 200706.zip
# Skipping file with invalid date format: 200705.zip
# Skipping file with invalid date format: 200704.zip
# Skipping file with invalid date format: 200703.zip
# Skipping file with invalid date format: 200702.zip
# Skipping file with invalid date format: 200701.zip
# Skipping file with invalid date format: 200612.zip
# Skipping file with invalid date format: 200611.zip
# Skipping file with invalid date format: 200610.zip
# Skipping file with invalid date format: 200609.zip
# Skipping file with invalid date format: 200608.zip
# Skipping file with invalid date format: 200607.zip
# Skipping file with invalid date format: 200606.zip
# Skipping file with invalid date format: 200605.zip
# Skipping file with invalid date format: 200604.zip
# Skipping file with invalid date format: 200603.zip
# Skipping file with invalid date format: 200602.zip
# Skipping file with invalid date format: 200601.zip
# Skipping file with invalid date format: 2005.zip
# Skipping file with invalid date format: 2004.zip
# Skipping file with invalid date format: 2003.zip
# Skipping file with invalid date format: 2002.zip
# Skipping file with invalid date format: 2001.zip
# Skipping file with invalid date format: 2000.zip
# Skipping file with invalid date format: 1999.zip
# Skipping file with invalid date format: 1998.zip
# Skipping file with invalid date format: 1997.zip
# Skipping file with invalid date format: 1996.zip
# Skipping file with invalid date format: 1995.zip
# Skipping file with invalid date format: 1994.zip
# Skipping file with invalid date format: 1993.zip
# Skipping file with invalid date format: 1992.zip
# Skipping file with invalid date format: 1991.zip
# Skipping file with invalid date format: 1990.zip
# Skipping file with invalid date format: 1989.zip
# Skipping file with invalid date format: 1988.zip
# Skipping file with invalid date format: 1987.zip
# Skipping file with invalid date format: 1986.zip
# Skipping file with invalid date format: 1985.zip
# Skipping file with invalid date format: 1984.zip
# Skipping file with invalid date format: 1983.zip
# Skipping file with invalid date format: 1982.zip
# Skipping file with invalid date format: 1981.zip
# Skipping file with invalid date format: 1980.zip
# Skipping file with invalid date format: 1979.zip
# Skipping file with invalid date format: GDELT.MASTERREDUCEDV2.1979-2013.zip
